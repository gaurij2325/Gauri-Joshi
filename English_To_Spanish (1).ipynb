# %%
# !pip install deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.11/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.12.14)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
import os
import pandas as pd
import configparser
from deep_translator import GoogleTranslator
import time
import logging

# Setup logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

# Directory paths
source_dir_path = "source"
translated_dir_path = "translated"
progress_dir_path = "progress"

# Language and translation settings
translated_dialect = "hi"  # Target language (Hindi in this case)
chunk_size = 30
max_translation_chunk_length = 4000  # Max characters per translation chunk
api_limit = 5000  # API limit on characters per request

# Ensure necessary directories exist
def ensure_directories_exist():
    os.makedirs(source_dir_path, exist_ok=True)
    os.makedirs(translated_dir_path, exist_ok=True)
    os.makedirs(progress_dir_path, exist_ok=True)

# Store dataset as CSV and start translation
def store_sft_dataset(name_of_dataset, data_frame, split_type):
    file_name = os.path.join(source_dir_path, f"{name_of_dataset.replace('/', '')}{split_type}.csv")
    if not os.path.isfile(file_name):
        logging.info(f"Creating file: {file_name}")
        data_frame.to_csv(file_name, encoding="utf-8", index=False, header=True)
        logging.info(f"File written: {file_name}")

    translate_in_dialects(name_of_dataset, data_frame, split_type, translated_dialect)

# Translate text with retries for reliability
def translate_text_with_retries(text, dest_language, retries=3, delay=10):
    attempt = 0
    while attempt < retries:
        try:
            if len(text) > max_translation_chunk_length:
                return translate_large_text(text, dest_language)
            return GoogleTranslator(source='auto', target=dest_language).translate(text)
        except Exception as e:
            logging.error(f"Translation attempt {attempt + 1} failed: {e}")
            attempt += 1
            time.sleep(delay)
    raise Exception(f"Failed to translate text after {retries} attempts")

# Handle large texts by chunking them for translation
def translate_large_text(text, dest_language):
    # Split the text into chunks
    chunks = split_text(text, max_translation_chunk_length)
    translated_chunks = []
    for chunk in chunks:
        try:
            translated_chunk = GoogleTranslator(source='auto', target=dest_language).translate(chunk)
            translated_chunks.append(translated_chunk)
        except Exception as e:
            logging.error(f"Error translating chunk: {e}")
            translated_chunks.append('')  # Append an empty string if there's an error
    return ''.join(translated_chunks)

# Split text into manageable chunks
def split_text(text, max_length):
    return [text[i:i + max_length] for i in range(0, len(text), max_length)]

# Save progress to a file
def save_progress(progress_file, last_translated_row):
    with open(progress_file, 'w') as f:
        f.write(str(last_translated_row))

# Load progress from a file
def load_progress(progress_file):
    if os.path.isfile(progress_file):
        with open(progress_file, 'r') as f:
            return int(f.read().strip())
    return 0

# Main translation function, handling datasets
def translate_in_dialects(name_of_dataset, data_frame, split_type, dialect_name="hi"):
    total_rows = len(data_frame)
    logging.info(f"Total rows to translate: {total_rows}")

    translated_file_name = os.path.join(translated_dir_path, f"{name_of_dataset.replace('/', '')}{split_type}_{dialect_name}_translated.csv")
    progress_file = os.path.join(progress_dir_path, f"{name_of_dataset.replace('/', '')}{split_type}_progress.txt")

    start_row = load_progress(progress_file)

    for chunk_start in range(start_row, total_rows, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_rows)
        chunk = data_frame.iloc[chunk_start:chunk_end]

        translated_append_list = []
        logging.info(f"Processing rows {chunk_start + 1} to {chunk_end}...")

        for index, row in chunk.iterrows():
            messages = row.get('messages', [])

            if not messages:
                logging.warning(f"Skipping row {index + 1} due to missing 'messages' field.")
                continue

            conversation_pairs = []
            turn_count = 0

            for i in range(0, len(messages), 2):
                if i + 1 < len(messages):
                    user_message = messages[i].get('content', '')
                    assistant_message = messages[i + 1].get('content', '')

                    if messages[i].get('role') == 'user' and messages[i + 1].get('role') == 'assistant':
                        try:
                            translated_user_message = translate_text_with_retries(user_message, dialect_name)
                            translated_assistant_message = translate_text_with_retries(assistant_message, dialect_name)

                            if translated_user_message:
                                conversation_pairs.append(translated_user_message)
                            if translated_assistant_message:
                                conversation_pairs.append(translated_assistant_message)

                            turn_count += 1
                        except Exception as e:
                            logging.error(f"Error translating pair at index {index}, pair {i // 2 + 1}: {e}")
                            continue

            if conversation_pairs:
                # Ensure all items are strings
                conversation_pairs = [str(item) for item in conversation_pairs if item is not None]
                translated_append_list.append({
                    'conversation': ' '.join(conversation_pairs),
                    'number_of_turns': turn_count
                })

                # Save progress after each row is translated successfully
                save_progress(progress_file, index)

        if translated_append_list:
            df = pd.DataFrame(translated_append_list, columns=['conversation', 'number_of_turns'])
            mode = 'w' if not os.path.isfile(translated_file_name) or chunk_start == start_row else 'a'
            header = not os.path.isfile(translated_file_name) or chunk_start == start_row
            df.to_csv(translated_file_name, encoding="utf-8", index=False, header=header, mode=mode)

            logging.info(f"Finished writing chunk {chunk_start + 1} to {chunk_end} to file {translated_file_name}")
        else:
            logging.info(f"No data to write for chunk {chunk_start + 1} to {chunk_end}.")

if __name__ == "__main__":
    ensure_directories_exist()
    config = configparser.ConfigParser()
    config.read(r"C:\Users\Nicole\Downloads\makers lab\SFT\Unconfirmed 786270.crdownload", encoding="utf-8")
    for key in config['sgpt']:
        if key.lower().strip() == "name":
            name_of_dataset = config['sgpt'][key].replace('"', '')
            splits = {"dataset": r"C:\Users\Nicole\Downloads\makers lab\SFT\source\sharegpt_entries1.json"}
            df_1 = pd.read_json(splits["dataset"])

            store_sft_dataset(name_of_dataset, df_1, "dataset")
# Out:
# 2024-08-21 20:14:26,103 - Creating file: source\sgptdataset.csv
# 2024-08-21 20:14:39,219 - File written: source\sgptdataset.csv
# 2024-08-21 20:14:39,221 - Total rows to translate: 41617
# 2024-08-21 20:14:39,223 - Processing rows 1 to 30...
# 2024-08-21 20:19:24,204 - Finished writing chunk 1 to 30 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:19:24,221 - Processing rows 31 to 60...
# 2024-08-21 20:23:19,226 - Finished writing chunk 31 to 60 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:23:19,228 - Processing rows 61 to 90...
# 2024-08-21 20:27:51,615 - Finished writing chunk 61 to 90 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:27:51,617 - Processing rows 91 to 120...
# 2024-08-21 20:31:59,666 - Finished writing chunk 91 to 120 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:31:59,668 - Processing rows 121 to 150...
# 2024-08-21 20:36:03,346 - Finished writing chunk 121 to 150 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:36:03,349 - Processing rows 151 to 180...
# 2024-08-21 20:39:53,226 - Finished writing chunk 151 to 180 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:39:53,228 - Processing rows 181 to 210...
# 2024-08-21 20:43:41,144 - Finished writing chunk 181 to 210 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:43:41,146 - Processing rows 211 to 240...
# 2024-08-21 20:46:27,985 - Finished writing chunk 211 to 240 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:46:27,987 - Processing rows 241 to 270...
# 2024-08-21 20:50:19,454 - Finished writing chunk 241 to 270 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:50:19,456 - Processing rows 271 to 300...
# 2024-08-21 20:55:35,703 - Finished writing chunk 271 to 300 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:55:35,705 - Processing rows 301 to 330...
# 2024-08-21 20:59:37,574 - Finished writing chunk 301 to 330 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 20:59:37,576 - Processing rows 331 to 360...
# 2024-08-21 21:02:45,938 - Finished writing chunk 331 to 360 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:02:45,940 - Processing rows 361 to 390...
# 2024-08-21 21:07:07,326 - Finished writing chunk 361 to 390 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:07:07,328 - Processing rows 391 to 420...
# 2024-08-21 21:10:52,680 - Finished writing chunk 391 to 420 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:10:52,682 - Processing rows 421 to 450...
# 2024-08-21 21:13:40,735 - Finished writing chunk 421 to 450 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:13:40,737 - Processing rows 451 to 480...
# 2024-08-21 21:18:05,898 - Finished writing chunk 451 to 480 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:18:05,900 - Processing rows 481 to 510...
# 2024-08-21 21:21:49,993 - Finished writing chunk 481 to 510 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:21:49,995 - Processing rows 511 to 540...
# 2024-08-21 21:25:38,943 - Finished writing chunk 511 to 540 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:25:38,945 - Processing rows 541 to 570...
# 2024-08-21 21:30:06,817 - Finished writing chunk 541 to 570 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:30:06,819 - Processing rows 571 to 600...
# 2024-08-21 21:33:52,521 - Finished writing chunk 571 to 600 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:33:52,523 - Processing rows 601 to 630...
# 2024-08-21 21:36:11,474 - Finished writing chunk 601 to 630 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:36:11,475 - Processing rows 631 to 660...
# 2024-08-21 21:39:01,370 - Finished writing chunk 631 to 660 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:39:01,373 - Processing rows 661 to 690...
# 2024-08-21 21:43:43,722 - Finished writing chunk 661 to 690 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:43:43,724 - Processing rows 691 to 720...
# 2024-08-21 21:46:58,548 - Finished writing chunk 691 to 720 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:46:58,549 - Processing rows 721 to 750...
# 2024-08-21 21:50:15,811 - Finished writing chunk 721 to 750 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:50:15,813 - Processing rows 751 to 780...
# 2024-08-21 21:54:09,613 - Finished writing chunk 751 to 780 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:54:09,617 - Processing rows 781 to 810...
# 2024-08-21 21:57:35,212 - Finished writing chunk 781 to 810 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 21:57:35,213 - Processing rows 811 to 840...
# 2024-08-21 22:03:25,917 - Finished writing chunk 811 to 840 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:03:25,918 - Processing rows 841 to 870...
# 2024-08-21 22:07:56,289 - Finished writing chunk 841 to 870 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:07:56,291 - Processing rows 871 to 900...
# 2024-08-21 22:10:19,390 - Finished writing chunk 871 to 900 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:10:19,392 - Processing rows 901 to 930...
# 2024-08-21 22:14:07,186 - Finished writing chunk 901 to 930 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:14:07,188 - Processing rows 931 to 960...
# 2024-08-21 22:17:59,419 - Finished writing chunk 931 to 960 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:17:59,421 - Processing rows 961 to 990...
# 2024-08-21 22:23:05,734 - Finished writing chunk 961 to 990 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:23:05,736 - Processing rows 991 to 1020...
# 2024-08-21 22:28:48,785 - Finished writing chunk 991 to 1020 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:28:48,787 - Processing rows 1021 to 1050...
# 2024-08-21 22:31:26,244 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-21 22:32:57,451 - Finished writing chunk 1021 to 1050 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:32:57,453 - Processing rows 1051 to 1080...
# 2024-08-21 22:39:08,776 - Finished writing chunk 1051 to 1080 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:39:08,778 - Processing rows 1081 to 1110...
# 2024-08-21 22:43:23,061 - Finished writing chunk 1081 to 1110 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:43:23,063 - Processing rows 1111 to 1140...
# 2024-08-21 22:46:14,179 - Finished writing chunk 1111 to 1140 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:46:14,181 - Processing rows 1141 to 1170...
# 2024-08-21 22:49:04,465 - Finished writing chunk 1141 to 1170 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:49:04,466 - Processing rows 1171 to 1200...
# 2024-08-21 22:53:51,930 - Finished writing chunk 1171 to 1200 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:53:52,024 - Processing rows 1201 to 1230...
# 2024-08-21 22:56:55,408 - Finished writing chunk 1201 to 1230 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 22:56:55,410 - Processing rows 1231 to 1260...
# 2024-08-21 23:00:48,617 - Finished writing chunk 1231 to 1260 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:00:48,618 - Processing rows 1261 to 1290...
# 2024-08-21 23:05:10,396 - Finished writing chunk 1261 to 1290 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:05:10,398 - Processing rows 1291 to 1320...
# 2024-08-21 23:08:41,657 - Finished writing chunk 1291 to 1320 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:08:41,658 - Processing rows 1321 to 1350...
# 2024-08-21 23:12:28,633 - Finished writing chunk 1321 to 1350 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:12:28,635 - Processing rows 1351 to 1380...
# 2024-08-21 23:15:56,716 - Finished writing chunk 1351 to 1380 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:15:56,718 - Processing rows 1381 to 1410...
# 2024-08-21 23:18:41,864 - Finished writing chunk 1381 to 1410 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:18:41,866 - Processing rows 1411 to 1440...
# 2024-08-21 23:22:49,999 - Finished writing chunk 1411 to 1440 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:22:50,001 - Processing rows 1441 to 1470...
# 2024-08-21 23:26:30,653 - Finished writing chunk 1441 to 1470 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:26:30,655 - Processing rows 1471 to 1500...
# 2024-08-21 23:31:18,337 - Finished writing chunk 1471 to 1500 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:31:18,339 - Processing rows 1501 to 1530...
# 2024-08-21 23:34:54,862 - Finished writing chunk 1501 to 1530 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:34:54,864 - Processing rows 1531 to 1560...
# 2024-08-21 23:38:20,789 - Finished writing chunk 1531 to 1560 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:38:20,791 - Processing rows 1561 to 1590...
# 2024-08-21 23:41:22,408 - Finished writing chunk 1561 to 1590 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:41:22,410 - Processing rows 1591 to 1620...
# 2024-08-21 23:46:50,565 - Finished writing chunk 1591 to 1620 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:46:50,567 - Processing rows 1621 to 1650...
# 2024-08-21 23:50:56,833 - Finished writing chunk 1621 to 1650 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:50:56,835 - Processing rows 1651 to 1680...
# 2024-08-21 23:55:09,502 - Finished writing chunk 1651 to 1680 to file translated\sgptdataset_hi_translated.csv
# 2024-08-21 23:55:09,503 - Processing rows 1681 to 1710...
# 2024-08-22 00:00:27,262 - Finished writing chunk 1681 to 1710 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:00:27,264 - Processing rows 1711 to 1740...
# 2024-08-22 00:03:34,585 - Finished writing chunk 1711 to 1740 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:03:34,586 - Processing rows 1741 to 1770...
# 2024-08-22 00:06:53,812 - Finished writing chunk 1741 to 1770 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:06:53,815 - Processing rows 1771 to 1800...
# 2024-08-22 00:12:51,397 - Finished writing chunk 1771 to 1800 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:12:51,399 - Processing rows 1801 to 1830...
# 2024-08-22 00:16:44,307 - Finished writing chunk 1801 to 1830 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:16:44,309 - Processing rows 1831 to 1860...
# 2024-08-22 00:20:49,699 - Finished writing chunk 1831 to 1860 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:20:49,701 - Processing rows 1861 to 1890...
# 2024-08-22 00:21:45,303 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 00:21:56,045 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 00:22:06,633 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 00:22:16,636 - Error translating pair at index 1870, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 00:24:37,555 - Finished writing chunk 1861 to 1890 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:24:37,557 - Processing rows 1891 to 1920...
# 2024-08-22 00:26:59,665 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 00:32:33,806 - Finished writing chunk 1891 to 1920 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:32:33,808 - Processing rows 1921 to 1950...
# 2024-08-22 00:37:13,752 - Finished writing chunk 1921 to 1950 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:37:13,754 - Processing rows 1951 to 1980...
# 2024-08-22 00:40:50,571 - Finished writing chunk 1951 to 1980 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:40:50,573 - Processing rows 1981 to 2010...
# 2024-08-22 00:44:45,620 - Finished writing chunk 1981 to 2010 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:44:45,622 - Processing rows 2011 to 2040...
# 2024-08-22 00:48:25,097 - Finished writing chunk 2011 to 2040 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:48:25,098 - Processing rows 2041 to 2070...
# 2024-08-22 00:54:04,710 - Finished writing chunk 2041 to 2070 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:54:04,712 - Processing rows 2071 to 2100...
# 2024-08-22 00:58:51,239 - Finished writing chunk 2071 to 2100 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 00:58:51,240 - Processing rows 2101 to 2130...
# 2024-08-22 01:03:42,886 - Finished writing chunk 2101 to 2130 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:03:42,888 - Processing rows 2131 to 2160...
# 2024-08-22 01:08:56,535 - Finished writing chunk 2131 to 2160 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:08:56,537 - Processing rows 2161 to 2190...
# 2024-08-22 01:13:13,276 - Finished writing chunk 2161 to 2190 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:13:13,277 - Processing rows 2191 to 2220...
# 2024-08-22 01:18:36,600 - Finished writing chunk 2191 to 2220 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:18:36,603 - Processing rows 2221 to 2250...
# 2024-08-22 01:25:10,320 - Finished writing chunk 2221 to 2250 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:25:10,322 - Processing rows 2251 to 2280...
# 2024-08-22 01:27:21,898 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 01:29:40,693 - Finished writing chunk 2251 to 2280 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:29:40,695 - Processing rows 2281 to 2310...
# 2024-08-22 01:33:32,465 - Finished writing chunk 2281 to 2310 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:33:32,468 - Processing rows 2311 to 2340...
# 2024-08-22 01:38:26,037 - Finished writing chunk 2311 to 2340 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:38:26,039 - Processing rows 2341 to 2370...
# 2024-08-22 01:43:36,616 - Finished writing chunk 2341 to 2370 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:43:36,617 - Processing rows 2371 to 2400...
# 2024-08-22 01:49:31,424 - Finished writing chunk 2371 to 2400 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:49:31,426 - Processing rows 2401 to 2430...
# 2024-08-22 01:52:20,752 - Translation attempt 1 failed: sequence item 1: expected str instance, NoneType found
# 2024-08-22 01:52:31,945 - Translation attempt 2 failed: sequence item 1: expected str instance, NoneType found
# 2024-08-22 01:52:42,713 - Translation attempt 3 failed: sequence item 1: expected str instance, NoneType found
# 2024-08-22 01:52:52,716 - Error translating pair at index 2424, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 01:53:33,913 - Finished writing chunk 2401 to 2430 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:53:33,914 - Processing rows 2431 to 2460...
# 2024-08-22 01:59:30,880 - Finished writing chunk 2431 to 2460 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 01:59:30,881 - Processing rows 2461 to 2490...
# 2024-08-22 02:03:39,226 - Finished writing chunk 2461 to 2490 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:03:39,228 - Processing rows 2491 to 2520...
# 2024-08-22 02:08:44,827 - Finished writing chunk 2491 to 2520 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:08:44,829 - Processing rows 2521 to 2550...
# 2024-08-22 02:12:35,846 - Finished writing chunk 2521 to 2550 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:12:35,848 - Processing rows 2551 to 2580...
# 2024-08-22 02:18:09,161 - Finished writing chunk 2551 to 2580 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:18:09,162 - Processing rows 2581 to 2610...
# 2024-08-22 02:23:47,803 - Finished writing chunk 2581 to 2610 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:23:47,805 - Processing rows 2611 to 2640...
# 2024-08-22 02:29:09,420 - Finished writing chunk 2611 to 2640 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:29:09,422 - Processing rows 2641 to 2670...
# 2024-08-22 02:36:23,593 - Finished writing chunk 2641 to 2670 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:36:23,594 - Processing rows 2671 to 2700...
# 2024-08-22 02:41:23,853 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 02:41:54,435 - Finished writing chunk 2671 to 2700 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:41:54,436 - Processing rows 2701 to 2730...
# 2024-08-22 02:46:52,829 - Finished writing chunk 2701 to 2730 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:46:52,831 - Processing rows 2731 to 2760...
# 2024-08-22 02:52:56,667 - Finished writing chunk 2731 to 2760 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:52:56,669 - Processing rows 2761 to 2790...
# 2024-08-22 02:58:34,807 - Finished writing chunk 2761 to 2790 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 02:58:34,808 - Processing rows 2791 to 2820...
# 2024-08-22 03:03:50,950 - Finished writing chunk 2791 to 2820 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:03:50,951 - Processing rows 2821 to 2850...
# 2024-08-22 03:08:39,253 - Finished writing chunk 2821 to 2850 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:08:39,254 - Processing rows 2851 to 2880...
# 2024-08-22 03:12:38,035 - Finished writing chunk 2851 to 2880 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:12:38,036 - Processing rows 2881 to 2910...
# 2024-08-22 03:18:37,062 - Finished writing chunk 2881 to 2910 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:18:37,064 - Processing rows 2911 to 2940...
# 2024-08-22 03:23:05,623 - Finished writing chunk 2911 to 2940 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:23:05,624 - Processing rows 2941 to 2970...
# 2024-08-22 03:30:34,045 - Finished writing chunk 2941 to 2970 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:30:34,047 - Processing rows 2971 to 3000...
# 2024-08-22 03:36:34,257 - Finished writing chunk 2971 to 3000 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:36:34,259 - Processing rows 3001 to 3030...
# 2024-08-22 03:42:50,701 - Finished writing chunk 3001 to 3030 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:42:50,703 - Processing rows 3031 to 3060...
# 2024-08-22 03:47:04,156 - Finished writing chunk 3031 to 3060 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:47:04,157 - Processing rows 3061 to 3090...
# 2024-08-22 03:52:14,681 - Finished writing chunk 3061 to 3090 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:52:14,683 - Processing rows 3091 to 3120...
# 2024-08-22 03:58:11,138 - Finished writing chunk 3091 to 3120 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 03:58:11,140 - Processing rows 3121 to 3150...
# 2024-08-22 04:02:31,247 - Finished writing chunk 3121 to 3150 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:02:31,249 - Processing rows 3151 to 3180...
# 2024-08-22 04:07:08,427 - Finished writing chunk 3151 to 3180 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:07:08,429 - Processing rows 3181 to 3210...
# 2024-08-22 04:13:35,642 - Finished writing chunk 3181 to 3210 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:13:35,644 - Processing rows 3211 to 3240...
# 2024-08-22 04:18:29,925 - Finished writing chunk 3211 to 3240 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:18:29,926 - Processing rows 3241 to 3270...
# 2024-08-22 04:24:10,106 - Finished writing chunk 3241 to 3270 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:24:10,108 - Processing rows 3271 to 3300...
# 2024-08-22 04:30:01,264 - Finished writing chunk 3271 to 3300 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:30:01,266 - Processing rows 3301 to 3330...
# 2024-08-22 04:35:33,928 - Finished writing chunk 3301 to 3330 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:35:33,930 - Processing rows 3331 to 3360...
# 2024-08-22 04:38:54,118 - Finished writing chunk 3331 to 3360 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:38:54,119 - Processing rows 3361 to 3390...
# 2024-08-22 04:43:16,914 - Finished writing chunk 3361 to 3390 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:43:16,916 - Processing rows 3391 to 3420...
# 2024-08-22 04:47:41,261 - Finished writing chunk 3391 to 3420 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:47:41,263 - Processing rows 3421 to 3450...
# 2024-08-22 04:52:15,081 - Finished writing chunk 3421 to 3450 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:52:15,082 - Processing rows 3451 to 3480...
# 2024-08-22 04:55:36,899 - Finished writing chunk 3451 to 3480 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 04:55:36,901 - Processing rows 3481 to 3510...
# 2024-08-22 05:01:03,477 - Finished writing chunk 3481 to 3510 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:01:03,479 - Processing rows 3511 to 3540...
# 2024-08-22 05:05:02,835 - Finished writing chunk 3511 to 3540 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:05:02,837 - Processing rows 3541 to 3570...
# 2024-08-22 05:10:32,261 - Finished writing chunk 3541 to 3570 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:10:32,263 - Processing rows 3571 to 3600...
# 2024-08-22 05:16:19,570 - Finished writing chunk 3571 to 3600 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:16:19,572 - Processing rows 3601 to 3630...
# 2024-08-22 05:21:52,298 - Finished writing chunk 3601 to 3630 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:21:52,300 - Processing rows 3631 to 3660...
# 2024-08-22 05:26:59,106 - Finished writing chunk 3631 to 3660 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:26:59,108 - Processing rows 3661 to 3690...
# 2024-08-22 05:30:56,512 - Finished writing chunk 3661 to 3690 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:30:56,514 - Processing rows 3691 to 3720...
# 2024-08-22 05:34:22,767 - Finished writing chunk 3691 to 3720 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:34:22,769 - Processing rows 3721 to 3750...
# 2024-08-22 05:39:08,912 - Finished writing chunk 3721 to 3750 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:39:08,914 - Processing rows 3751 to 3780...
# 2024-08-22 05:44:38,929 - Finished writing chunk 3751 to 3780 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:44:38,931 - Processing rows 3781 to 3810...
# 2024-08-22 05:50:39,735 - Finished writing chunk 3781 to 3810 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:50:39,738 - Processing rows 3811 to 3840...
# 2024-08-22 05:55:22,906 - Finished writing chunk 3811 to 3840 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 05:55:22,907 - Processing rows 3841 to 3870...
# 2024-08-22 06:00:29,909 - Finished writing chunk 3841 to 3870 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:00:29,911 - Processing rows 3871 to 3900...
# 2024-08-22 06:04:37,183 - Finished writing chunk 3871 to 3900 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:04:37,185 - Processing rows 3901 to 3930...
# 2024-08-22 06:08:59,040 - Finished writing chunk 3901 to 3930 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:08:59,041 - Processing rows 3931 to 3960...
# 2024-08-22 06:13:36,181 - Finished writing chunk 3931 to 3960 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:13:36,183 - Processing rows 3961 to 3990...
# 2024-08-22 06:17:55,338 - Finished writing chunk 3961 to 3990 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:17:55,340 - Processing rows 3991 to 4020...
# 2024-08-22 06:20:31,105 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 06:24:51,862 - Finished writing chunk 3991 to 4020 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:24:51,864 - Processing rows 4021 to 4050...
# 2024-08-22 06:29:35,843 - Finished writing chunk 4021 to 4050 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:29:35,845 - Processing rows 4051 to 4080...
# 2024-08-22 06:32:20,421 - Finished writing chunk 4051 to 4080 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:32:20,423 - Processing rows 4081 to 4110...
# 2024-08-22 06:37:24,978 - Finished writing chunk 4081 to 4110 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:37:24,981 - Processing rows 4111 to 4140...
# 2024-08-22 06:40:02,013 - Finished writing chunk 4111 to 4140 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:40:02,015 - Processing rows 4141 to 4170...
# 2024-08-22 06:44:36,658 - Finished writing chunk 4141 to 4170 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:44:36,660 - Processing rows 4171 to 4200...
# 2024-08-22 06:50:23,204 - Finished writing chunk 4171 to 4200 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:50:23,206 - Processing rows 4201 to 4230...
# 2024-08-22 06:52:49,899 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 06:53:00,557 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 06:53:10,880 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 06:53:20,883 - Error translating pair at index 4212, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 06:55:27,193 - Finished writing chunk 4201 to 4230 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 06:55:27,195 - Processing rows 4231 to 4260...
# 2024-08-22 06:56:24,586 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 06:57:06,120 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 06:58:20,790 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 07:02:55,266 - Finished writing chunk 4231 to 4260 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:02:55,268 - Processing rows 4261 to 4290...
# 2024-08-22 07:07:19,903 - Finished writing chunk 4261 to 4290 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:07:19,904 - Processing rows 4291 to 4320...
# 2024-08-22 07:11:59,121 - Finished writing chunk 4291 to 4320 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:11:59,124 - Processing rows 4321 to 4350...
# 2024-08-22 07:17:48,124 - Finished writing chunk 4321 to 4350 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:17:48,126 - Processing rows 4351 to 4380...
# 2024-08-22 07:22:08,838 - Finished writing chunk 4351 to 4380 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:22:08,839 - Processing rows 4381 to 4410...
# 2024-08-22 07:26:24,446 - Finished writing chunk 4381 to 4410 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:26:24,448 - Processing rows 4411 to 4440...
# 2024-08-22 07:33:05,490 - Finished writing chunk 4411 to 4440 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:33:05,492 - Processing rows 4441 to 4470...
# 2024-08-22 07:38:19,350 - Finished writing chunk 4441 to 4470 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:38:19,352 - Processing rows 4471 to 4500...
# 2024-08-22 07:44:21,214 - Finished writing chunk 4471 to 4500 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:44:21,216 - Processing rows 4501 to 4530...
# 2024-08-22 07:49:09,764 - Finished writing chunk 4501 to 4530 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:49:09,765 - Processing rows 4531 to 4560...
# 2024-08-22 07:53:09,363 - Finished writing chunk 4531 to 4560 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:53:09,364 - Processing rows 4561 to 4590...
# 2024-08-22 07:58:02,435 - Finished writing chunk 4561 to 4590 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 07:58:02,437 - Processing rows 4591 to 4620...
# 2024-08-22 08:04:50,965 - Finished writing chunk 4591 to 4620 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:04:50,967 - Processing rows 4621 to 4650...
# 2024-08-22 08:11:48,506 - Finished writing chunk 4621 to 4650 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:11:48,507 - Processing rows 4651 to 4680...
# 2024-08-22 08:15:54,173 - Finished writing chunk 4651 to 4680 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:15:54,173 - Processing rows 4681 to 4710...
# 2024-08-22 08:18:53,582 - Finished writing chunk 4681 to 4710 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:18:53,583 - Processing rows 4711 to 4740...
# 2024-08-22 08:23:01,947 - Finished writing chunk 4711 to 4740 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:23:01,948 - Processing rows 4741 to 4770...
# 2024-08-22 08:27:09,708 - Finished writing chunk 4741 to 4770 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:27:09,710 - Processing rows 4771 to 4800...
# 2024-08-22 08:30:20,955 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 08:31:03,397 - Finished writing chunk 4771 to 4800 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:31:03,399 - Processing rows 4801 to 4830...
# 2024-08-22 08:35:00,829 - Finished writing chunk 4801 to 4830 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:35:00,831 - Processing rows 4831 to 4860...
# 2024-08-22 08:35:41,845 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 08:38:26,633 - Finished writing chunk 4831 to 4860 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:38:26,635 - Processing rows 4861 to 4890...
# 2024-08-22 08:42:59,271 - Finished writing chunk 4861 to 4890 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:42:59,272 - Processing rows 4891 to 4920...
# 2024-08-22 08:47:03,615 - Finished writing chunk 4891 to 4920 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:47:03,616 - Processing rows 4921 to 4950...
# 2024-08-22 08:50:54,130 - Finished writing chunk 4921 to 4950 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:50:54,132 - Processing rows 4951 to 4980...
# 2024-08-22 08:54:12,851 - Finished writing chunk 4951 to 4980 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:54:12,852 - Processing rows 4981 to 5010...
# 2024-08-22 08:58:14,432 - Finished writing chunk 4981 to 5010 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 08:58:14,433 - Processing rows 5011 to 5040...
# 2024-08-22 09:02:16,419 - Finished writing chunk 5011 to 5040 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:02:16,420 - Processing rows 5041 to 5070...
# 2024-08-22 09:06:50,919 - Finished writing chunk 5041 to 5070 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:06:50,921 - Processing rows 5071 to 5100...
# 2024-08-22 09:09:55,951 - Finished writing chunk 5071 to 5100 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:09:55,953 - Processing rows 5101 to 5130...
# 2024-08-22 09:13:14,251 - Finished writing chunk 5101 to 5130 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:13:14,253 - Processing rows 5131 to 5160...
# 2024-08-22 09:17:20,560 - Finished writing chunk 5131 to 5160 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:17:20,562 - Processing rows 5161 to 5190...
# 2024-08-22 09:20:39,902 - Finished writing chunk 5161 to 5190 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:20:39,903 - Processing rows 5191 to 5220...
# 2024-08-22 09:24:22,665 - Finished writing chunk 5191 to 5220 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:24:22,666 - Processing rows 5221 to 5250...
# 2024-08-22 09:27:34,628 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 09:28:20,854 - Finished writing chunk 5221 to 5250 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:28:20,856 - Processing rows 5251 to 5280...
# 2024-08-22 09:32:15,899 - Finished writing chunk 5251 to 5280 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:32:15,900 - Processing rows 5281 to 5310...
# 2024-08-22 09:36:52,771 - Finished writing chunk 5281 to 5310 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:36:52,772 - Processing rows 5311 to 5340...
# 2024-08-22 09:40:37,084 - Finished writing chunk 5311 to 5340 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:40:37,086 - Processing rows 5341 to 5370...
# 2024-08-22 09:44:26,462 - Finished writing chunk 5341 to 5370 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:44:26,463 - Processing rows 5371 to 5400...
# 2024-08-22 09:48:50,192 - Finished writing chunk 5371 to 5400 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:48:50,194 - Processing rows 5401 to 5430...
# 2024-08-22 09:55:14,242 - Finished writing chunk 5401 to 5430 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 09:55:14,243 - Processing rows 5431 to 5460...
# 2024-08-22 10:00:03,484 - Finished writing chunk 5431 to 5460 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:00:03,486 - Processing rows 5461 to 5490...
# 2024-08-22 10:06:01,097 - Finished writing chunk 5461 to 5490 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:06:01,099 - Processing rows 5491 to 5520...
# 2024-08-22 10:10:29,784 - Finished writing chunk 5491 to 5520 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:10:29,785 - Processing rows 5521 to 5550...
# 2024-08-22 10:13:41,806 - Finished writing chunk 5521 to 5550 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:13:41,808 - Processing rows 5551 to 5580...
# 2024-08-22 10:18:26,131 - Finished writing chunk 5551 to 5580 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:18:26,132 - Processing rows 5581 to 5610...
# 2024-08-22 10:23:56,056 - Finished writing chunk 5581 to 5610 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:23:56,057 - Processing rows 5611 to 5640...
# 2024-08-22 10:27:58,744 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 10:28:39,779 - Finished writing chunk 5611 to 5640 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:28:39,781 - Processing rows 5641 to 5670...
# 2024-08-22 10:32:40,839 - Finished writing chunk 5641 to 5670 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:32:40,841 - Processing rows 5671 to 5700...
# 2024-08-22 10:36:17,429 - Finished writing chunk 5671 to 5700 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:36:17,430 - Processing rows 5701 to 5730...
# 2024-08-22 10:41:05,082 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:41:16,303 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:41:26,588 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:41:36,591 - Error translating pair at index 5728, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 10:41:37,235 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:41:47,508 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:41:57,848 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 10:42:07,850 - Error translating pair at index 5729, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 10:42:11,190 - Finished writing chunk 5701 to 5730 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:42:11,191 - Processing rows 5731 to 5760...
# 2024-08-22 10:46:42,156 - Finished writing chunk 5731 to 5760 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:46:42,158 - Processing rows 5761 to 5790...
# 2024-08-22 10:50:08,421 - Finished writing chunk 5761 to 5790 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:50:08,423 - Processing rows 5791 to 5820...
# 2024-08-22 10:55:32,809 - Finished writing chunk 5791 to 5820 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 10:55:32,811 - Processing rows 5821 to 5850...
# 2024-08-22 11:00:01,023 - Finished writing chunk 5821 to 5850 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:00:01,024 - Processing rows 5851 to 5880...
# 2024-08-22 11:05:21,695 - Finished writing chunk 5851 to 5880 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:05:21,696 - Processing rows 5881 to 5910...
# 2024-08-22 11:09:10,734 - Finished writing chunk 5881 to 5910 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:09:10,736 - Processing rows 5911 to 5940...
# 2024-08-22 11:12:34,123 - Finished writing chunk 5911 to 5940 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:12:34,125 - Processing rows 5941 to 5970...
# 2024-08-22 11:15:56,693 - Finished writing chunk 5941 to 5970 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:15:56,695 - Processing rows 5971 to 6000...
# 2024-08-22 11:20:02,948 - Finished writing chunk 5971 to 6000 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:20:02,950 - Processing rows 6001 to 6030...
# 2024-08-22 11:23:30,456 - Finished writing chunk 6001 to 6030 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:23:30,459 - Processing rows 6031 to 6060...
# 2024-08-22 11:27:18,919 - Finished writing chunk 6031 to 6060 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:27:18,921 - Processing rows 6061 to 6090...
# 2024-08-22 11:31:01,734 - Finished writing chunk 6061 to 6090 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:31:01,736 - Processing rows 6091 to 6120...
# 2024-08-22 11:33:53,387 - Finished writing chunk 6091 to 6120 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:33:53,388 - Processing rows 6121 to 6150...
# 2024-08-22 11:38:04,396 - Finished writing chunk 6121 to 6150 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:38:04,398 - Processing rows 6151 to 6180...
# 2024-08-22 11:41:54,784 - Finished writing chunk 6151 to 6180 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:41:54,817 - Processing rows 6181 to 6210...
# 2024-08-22 11:43:56,199 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 11:44:06,740 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 11:44:17,081 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-22 11:44:27,084 - Error translating pair at index 6198, pair 1: Failed to translate text after 3 attempts
# 2024-08-22 11:45:58,698 - Finished writing chunk 6181 to 6210 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:45:58,701 - Processing rows 6211 to 6240...
# 2024-08-22 11:49:16,282 - Finished writing chunk 6211 to 6240 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:49:16,283 - Processing rows 6241 to 6270...
# 2024-08-22 11:54:42,076 - Finished writing chunk 6241 to 6270 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:54:42,078 - Processing rows 6271 to 6300...
# 2024-08-22 11:59:14,709 - Finished writing chunk 6271 to 6300 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 11:59:14,711 - Processing rows 6301 to 6330...
# 2024-08-22 12:01:45,866 - Finished writing chunk 6301 to 6330 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:01:45,869 - Processing rows 6331 to 6360...
# 2024-08-22 12:05:23,598 - Finished writing chunk 6331 to 6360 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:05:23,600 - Processing rows 6361 to 6390...
# 2024-08-22 12:09:40,369 - Finished writing chunk 6361 to 6390 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:09:40,370 - Processing rows 6391 to 6420...
# 2024-08-22 12:14:37,152 - Finished writing chunk 6391 to 6420 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:14:37,155 - Processing rows 6421 to 6450...
# 2024-08-22 12:18:20,555 - Finished writing chunk 6421 to 6450 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:18:20,638 - Processing rows 6451 to 6480...
# 2024-08-22 12:22:59,937 - Finished writing chunk 6451 to 6480 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:22:59,939 - Processing rows 6481 to 6510...
# 2024-08-22 12:27:12,487 - Finished writing chunk 6481 to 6510 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:27:12,489 - Processing rows 6511 to 6540...
# 2024-08-22 12:30:15,375 - Finished writing chunk 6511 to 6540 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:30:15,377 - Processing rows 6541 to 6570...
# 2024-08-22 12:33:10,426 - Finished writing chunk 6541 to 6570 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:33:10,429 - Processing rows 6571 to 6600...
# 2024-08-22 12:37:18,258 - Finished writing chunk 6571 to 6600 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:37:18,260 - Processing rows 6601 to 6630...
# 2024-08-22 12:41:57,830 - Translation attempt 1 failed: ('Connection aborted.', ConnectionAbortedError(10053, 'An established connection was aborted by the software in your host machine', None, 10053, None))
# 2024-08-22 12:42:16,290 - Finished writing chunk 6601 to 6630 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:42:16,292 - Processing rows 6631 to 6660...
# 2024-08-22 12:43:18,058 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 12:45:02,355 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 12:50:09,033 - Finished writing chunk 6631 to 6660 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:50:09,036 - Processing rows 6661 to 6690...
# 2024-08-22 12:50:49,556 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 12:52:20,658 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 12:56:08,352 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 12:56:37,815 - Finished writing chunk 6661 to 6690 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 12:56:37,817 - Processing rows 6691 to 6720...
# 2024-08-22 13:01:16,408 - Finished writing chunk 6691 to 6720 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:01:16,410 - Processing rows 6721 to 6750...
# 2024-08-22 13:04:10,514 - Finished writing chunk 6721 to 6750 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:04:10,517 - Processing rows 6751 to 6780...
# 2024-08-22 13:08:32,953 - Finished writing chunk 6751 to 6780 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:08:32,956 - Processing rows 6781 to 6810...
# 2024-08-22 13:09:02,177 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 13:16:43,026 - Finished writing chunk 6781 to 6810 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:16:43,028 - Processing rows 6811 to 6840...
# 2024-08-22 13:20:37,987 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-22 13:23:16,461 - Finished writing chunk 6811 to 6840 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:23:16,463 - Processing rows 6841 to 6870...
# 2024-08-22 13:28:10,263 - Finished writing chunk 6841 to 6870 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:28:10,265 - Processing rows 6871 to 6900...
# 2024-08-22 13:32:30,700 - Finished writing chunk 6871 to 6900 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:32:30,702 - Processing rows 6901 to 6930...
# 2024-08-22 13:36:50,699 - Finished writing chunk 6901 to 6930 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:36:50,701 - Processing rows 6931 to 6960...
# 2024-08-22 13:40:52,727 - Finished writing chunk 6931 to 6960 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:40:52,729 - Processing rows 6961 to 6990...
# 2024-08-22 13:44:34,809 - Finished writing chunk 6961 to 6990 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:44:34,811 - Processing rows 6991 to 7020...
# 2024-08-22 13:48:48,440 - Finished writing chunk 6991 to 7020 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:48:48,442 - Processing rows 7021 to 7050...
# 2024-08-22 13:52:22,186 - Finished writing chunk 7021 to 7050 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:52:22,188 - Processing rows 7051 to 7080...
# 2024-08-22 13:57:35,293 - Finished writing chunk 7051 to 7080 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 13:57:35,295 - Processing rows 7081 to 7110...
# 2024-08-22 14:02:08,301 - Finished writing chunk 7081 to 7110 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:02:08,303 - Processing rows 7111 to 7140...
# 2024-08-22 14:08:11,331 - Finished writing chunk 7111 to 7140 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:08:11,332 - Processing rows 7141 to 7170...
# 2024-08-22 14:12:16,602 - Finished writing chunk 7141 to 7170 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:12:16,603 - Processing rows 7171 to 7200...
# 2024-08-22 14:18:33,739 - Finished writing chunk 7171 to 7200 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:18:33,742 - Processing rows 7201 to 7230...
# 2024-08-22 14:22:51,531 - Finished writing chunk 7201 to 7230 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:22:51,534 - Processing rows 7231 to 7260...
# 2024-08-22 14:27:41,459 - Finished writing chunk 7231 to 7260 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:27:41,460 - Processing rows 7261 to 7290...
# 2024-08-22 14:31:21,567 - Finished writing chunk 7261 to 7290 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:31:21,569 - Processing rows 7291 to 7320...
# 2024-08-22 14:38:02,364 - Finished writing chunk 7291 to 7320 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:38:02,366 - Processing rows 7321 to 7350...
# 2024-08-22 14:42:33,548 - Finished writing chunk 7321 to 7350 to file translated\sgptdataset_hi_translated.csv
# 2024-08-22 14:42:33,551 - Processing rows 7351 to 7380...
# ...
# 2024-08-25 19:57:56,016 - Processing rows 39211 to 39240...
# 2024-08-25 20:01:49,628 - Finished writing chunk 39211 to 39240 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:01:49,630 - Processing rows 39241 to 39270...
# 2024-08-25 20:04:31,858 - Translation attempt 1 failed: sequence item 2: expected str instance, NoneType found
# 2024-08-25 20:04:42,829 - Translation attempt 2 failed: sequence item 2: expected str instance, NoneType found
# 2024-08-25 20:04:57,429 - Translation attempt 3 failed: sequence item 2: expected str instance, NoneType found
# 2024-08-25 20:05:07,431 - Error translating pair at index 39253, pair 1: Failed to translate text after 3 attempts
# 2024-08-25 20:06:40,022 - Finished writing chunk 39241 to 39270 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:06:40,024 - Processing rows 39271 to 39300...
# 2024-08-25 20:09:52,494 - Finished writing chunk 39271 to 39300 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:09:52,497 - Processing rows 39301 to 39330...
# 2024-08-25 20:12:33,274 - Finished writing chunk 39301 to 39330 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:12:33,276 - Processing rows 39331 to 39360...
# 2024-08-25 20:17:09,900 - Finished writing chunk 39331 to 39360 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:17:09,903 - Processing rows 39361 to 39390...
# 2024-08-25 20:21:54,462 - Finished writing chunk 39361 to 39390 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:21:54,464 - Processing rows 39391 to 39420...
# 2024-08-25 20:26:31,296 - Finished writing chunk 39391 to 39420 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:26:31,298 - Processing rows 39421 to 39450...
# 2024-08-25 20:30:03,430 - Finished writing chunk 39421 to 39450 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:30:03,432 - Processing rows 39451 to 39480...
# 2024-08-25 20:33:19,360 - Finished writing chunk 39451 to 39480 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:33:19,362 - Processing rows 39481 to 39510...
# 2024-08-25 20:38:19,491 - Finished writing chunk 39481 to 39510 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:38:19,493 - Processing rows 39511 to 39540...
# 2024-08-25 20:42:45,251 - Finished writing chunk 39511 to 39540 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:42:45,254 - Processing rows 39541 to 39570...
# 2024-08-25 20:46:03,098 - Finished writing chunk 39541 to 39570 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:46:03,100 - Processing rows 39571 to 39600...
# 2024-08-25 20:49:29,994 - Finished writing chunk 39571 to 39600 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:49:29,995 - Processing rows 39601 to 39630...
# 2024-08-25 20:56:56,810 - Finished writing chunk 39601 to 39630 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 20:56:56,813 - Processing rows 39631 to 39660...
# 2024-08-25 21:01:10,557 - Finished writing chunk 39631 to 39660 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:01:10,559 - Processing rows 39661 to 39690...
# 2024-08-25 21:04:34,998 - Finished writing chunk 39661 to 39690 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:04:35,000 - Processing rows 39691 to 39720...
# 2024-08-25 21:08:26,010 - Finished writing chunk 39691 to 39720 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:08:26,013 - Processing rows 39721 to 39750...
# 2024-08-25 21:12:45,239 - Finished writing chunk 39721 to 39750 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:12:45,241 - Processing rows 39751 to 39780...
# 2024-08-25 21:16:00,896 - Finished writing chunk 39751 to 39780 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:16:00,897 - Processing rows 39781 to 39810...
# 2024-08-25 21:20:57,338 - Finished writing chunk 39781 to 39810 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:20:57,340 - Processing rows 39811 to 39840...
# 2024-08-25 21:23:51,787 - Finished writing chunk 39811 to 39840 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:23:51,789 - Processing rows 39841 to 39870...
# 2024-08-25 21:27:10,642 - Finished writing chunk 39841 to 39870 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:27:10,643 - Processing rows 39871 to 39900...
# 2024-08-25 21:32:33,303 - Finished writing chunk 39871 to 39900 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:32:33,304 - Processing rows 39901 to 39930...
# 2024-08-25 21:37:22,620 - Finished writing chunk 39901 to 39930 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:37:22,622 - Processing rows 39931 to 39960...
# 2024-08-25 21:41:59,788 - Finished writing chunk 39931 to 39960 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:41:59,790 - Processing rows 39961 to 39990...
# 2024-08-25 21:47:01,737 - Finished writing chunk 39961 to 39990 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:47:01,738 - Processing rows 39991 to 40020...
# 2024-08-25 21:50:42,814 - Finished writing chunk 39991 to 40020 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:50:42,816 - Processing rows 40021 to 40050...
# 2024-08-25 21:55:24,633 - Finished writing chunk 40021 to 40050 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:55:24,635 - Processing rows 40051 to 40080...
# 2024-08-25 21:58:11,562 - Finished writing chunk 40051 to 40080 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 21:58:11,563 - Processing rows 40081 to 40110...
# 2024-08-25 22:01:58,770 - Finished writing chunk 40081 to 40110 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:01:58,772 - Processing rows 40111 to 40140...
# 2024-08-25 22:04:49,785 - Finished writing chunk 40111 to 40140 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:04:49,787 - Processing rows 40141 to 40170...
# 2024-08-25 22:08:33,921 - Finished writing chunk 40141 to 40170 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:08:33,922 - Processing rows 40171 to 40200...
# 2024-08-25 22:14:34,194 - Finished writing chunk 40171 to 40200 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:14:34,196 - Processing rows 40201 to 40230...
# 2024-08-25 22:19:09,299 - Finished writing chunk 40201 to 40230 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:19:09,301 - Processing rows 40231 to 40260...
# 2024-08-25 22:22:59,230 - Finished writing chunk 40231 to 40260 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:22:59,233 - Processing rows 40261 to 40290...
# 2024-08-25 22:26:56,620 - Finished writing chunk 40261 to 40290 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:26:56,621 - Processing rows 40291 to 40320...
# 2024-08-25 22:30:38,297 - Finished writing chunk 40291 to 40320 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:30:38,299 - Processing rows 40321 to 40350...
# 2024-08-25 22:34:49,985 - Finished writing chunk 40321 to 40350 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:34:49,987 - Processing rows 40351 to 40380...
# 2024-08-25 22:42:15,435 - Finished writing chunk 40351 to 40380 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:42:15,436 - Processing rows 40381 to 40410...
# 2024-08-25 22:51:15,095 - Finished writing chunk 40381 to 40410 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:51:15,097 - Processing rows 40411 to 40440...
# 2024-08-25 22:57:10,220 - Finished writing chunk 40411 to 40440 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 22:57:10,222 - Processing rows 40441 to 40470...
# 2024-08-25 23:02:19,494 - Finished writing chunk 40441 to 40470 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:02:19,496 - Processing rows 40471 to 40500...
# 2024-08-25 23:07:07,681 - Finished writing chunk 40471 to 40500 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:07:07,684 - Processing rows 40501 to 40530...
# 2024-08-25 23:17:11,916 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:17:22,428 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:17:32,669 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:17:42,671 - Error translating pair at index 40523, pair 1: Failed to translate text after 3 attempts
# 2024-08-25 23:19:57,807 - Finished writing chunk 40501 to 40530 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:19:57,808 - Processing rows 40531 to 40560...
# 2024-08-25 23:26:29,178 - Finished writing chunk 40531 to 40560 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:26:29,181 - Processing rows 40561 to 40590...
# 2024-08-25 23:31:32,234 - Finished writing chunk 40561 to 40590 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:31:32,236 - Processing rows 40591 to 40620...
# 2024-08-25 23:36:01,898 - Finished writing chunk 40591 to 40620 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:36:01,900 - Processing rows 40621 to 40650...
# 2024-08-25 23:38:19,191 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-25 23:41:21,458 - Finished writing chunk 40621 to 40650 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:41:21,459 - Processing rows 40651 to 40680...
# 2024-08-25 23:41:28,193 - Translation attempt 1 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:41:38,430 - Translation attempt 2 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:41:49,089 - Translation attempt 3 failed: Request exception can happen due to an api connection error. Please check your connection and try again
# 2024-08-25 23:41:59,092 - Error translating pair at index 40652, pair 1: Failed to translate text after 3 attempts
# 2024-08-25 23:44:35,621 - Finished writing chunk 40651 to 40680 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:44:35,623 - Processing rows 40681 to 40710...
# 2024-08-25 23:47:16,281 - Finished writing chunk 40681 to 40710 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:47:16,282 - Processing rows 40711 to 40740...
# 2024-08-25 23:52:11,870 - Finished writing chunk 40711 to 40740 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:52:11,871 - Processing rows 40741 to 40770...
# 2024-08-25 23:53:11,138 - Translation attempt 1 failed: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-08-25 23:55:31,142 - Finished writing chunk 40741 to 40770 to file translated\sgptdataset_hi_translated.csv
# 2024-08-25 23:55:31,144 - Processing rows 40771 to 40800...
# 2024-08-26 00:02:21,134 - Finished writing chunk 40771 to 40800 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:02:21,135 - Processing rows 40801 to 40830...
# 2024-08-26 00:06:43,460 - Finished writing chunk 40801 to 40830 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:06:43,462 - Processing rows 40831 to 40860...
# 2024-08-26 00:10:04,388 - Finished writing chunk 40831 to 40860 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:10:04,389 - Processing rows 40861 to 40890...
# 2024-08-26 00:13:59,508 - Finished writing chunk 40861 to 40890 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:13:59,510 - Processing rows 40891 to 40920...
# 2024-08-26 00:16:55,825 - Finished writing chunk 40891 to 40920 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:16:55,826 - Processing rows 40921 to 40950...
# 2024-08-26 00:20:18,607 - Finished writing chunk 40921 to 40950 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:20:18,609 - Processing rows 40951 to 40980...
# 2024-08-26 00:24:33,060 - Finished writing chunk 40951 to 40980 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:24:33,062 - Processing rows 40981 to 41010...
# 2024-08-26 00:28:30,428 - Finished writing chunk 40981 to 41010 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:28:30,429 - Processing rows 41011 to 41040...
# 2024-08-26 00:33:44,551 - Finished writing chunk 41011 to 41040 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:33:44,553 - Processing rows 41041 to 41070...
# 2024-08-26 00:39:05,080 - Finished writing chunk 41041 to 41070 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:39:05,081 - Processing rows 41071 to 41100...
# 2024-08-26 00:44:34,690 - Finished writing chunk 41071 to 41100 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:44:34,692 - Processing rows 41101 to 41130...
# 2024-08-26 00:48:02,791 - Finished writing chunk 41101 to 41130 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:48:02,793 - Processing rows 41131 to 41160...
# 2024-08-26 00:52:57,769 - Finished writing chunk 41131 to 41160 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:52:57,771 - Processing rows 41161 to 41190...
# 2024-08-26 00:56:36,741 - Finished writing chunk 41161 to 41190 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 00:56:36,743 - Processing rows 41191 to 41220...
# 2024-08-26 01:03:27,727 - Finished writing chunk 41191 to 41220 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:03:27,730 - Processing rows 41221 to 41250...
# 2024-08-26 01:09:07,586 - Finished writing chunk 41221 to 41250 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:09:07,588 - Processing rows 41251 to 41280...
# 2024-08-26 01:13:00,292 - Finished writing chunk 41251 to 41280 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:13:00,294 - Processing rows 41281 to 41310...
# 2024-08-26 01:16:22,672 - Finished writing chunk 41281 to 41310 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:16:22,675 - Processing rows 41311 to 41340...
# 2024-08-26 01:20:56,184 - Finished writing chunk 41311 to 41340 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:20:56,185 - Processing rows 41341 to 41370...
# 2024-08-26 01:26:48,543 - Finished writing chunk 41341 to 41370 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:26:48,545 - Processing rows 41371 to 41400...
# 2024-08-26 01:30:24,430 - Finished writing chunk 41371 to 41400 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:30:24,432 - Processing rows 41401 to 41430...
# 2024-08-26 01:37:29,883 - Finished writing chunk 41401 to 41430 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:37:29,885 - Processing rows 41431 to 41460...
# 2024-08-26 01:41:59,662 - Finished writing chunk 41431 to 41460 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:41:59,663 - Processing rows 41461 to 41490...
# 2024-08-26 01:46:26,985 - Finished writing chunk 41461 to 41490 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:46:26,986 - Processing rows 41491 to 41520...
# 2024-08-26 01:51:15,773 - Finished writing chunk 41491 to 41520 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:51:15,775 - Processing rows 41521 to 41550...
# 2024-08-26 01:55:29,593 - Finished writing chunk 41521 to 41550 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:55:29,595 - Processing rows 41551 to 41580...
# 2024-08-26 01:59:52,821 - Finished writing chunk 41551 to 41580 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 01:59:52,823 - Processing rows 41581 to 41610...
# 2024-08-26 02:04:01,765 - Finished writing chunk 41581 to 41610 to file translated\sgptdataset_hi_translated.csv
# 2024-08-26 02:04:01,767 - Processing rows 41611 to 41617...
# 2024-08-26 02:04:38,732 - Finished writing chunk 41611 to 41617 to file translated\sgptdataset_hi_translated.csv

# %%
import os
import pandas as pd
import configparser
from deep_translator import GoogleTranslator
import time
import torch
import random

source_dir_path = "source"
translated_dir_path = "translated"
progress_dir_path = "progress"
config = configparser.ConfigParser(default_section="DATASETS")

translated_dialect = "hi"
chunk_size = 100

device = "cuda" if torch.cuda.is_available() else "cpu"

def ensure_directories_exist():
    os.makedirs(source_dir_path, exist_ok=True)
    os.makedirs(translated_dir_path, exist_ok=True)
    os.makedirs(progress_dir_path, exist_ok=True)

def store_sft_dataset(name_of_dataset, data_frame, split_type):
    file_name = str(os.path.join(source_dir_path, name_of_dataset.replace("/", "_"))) + "train.csv"
    if not os.path.isfile(file_name):
        print("Opening file.....", file_name)
        data_frame.to_csv(file_name, index=False, header=True, encoding='utf-8-sig')  # Specify encoding
        print("Finished writing file....", file_name)


    translate_in_dialects(name_of_dataset, data_frame, split_type, translated_dialect)

def translate_text_with_retries(text, dest_language, retries=3, delay=5):
    attempt = 0
    translator = GoogleTranslator(source='auto', target=dest_language)
    while attempt < retries:
        try:
            return translator.translate(text)
        except Exception as e:
            print(f"Translation attempt {attempt + 1} failed: {e}")
            attempt += 1
            time.sleep(delay)
    raise Exception(f"Failed to translate text after {retries} attempts")

def translate_in_dialects(name_of_dataset, data_frame, split_type, dialect_name="hi"):
    total_rows = len(data_frame)
    print(f"Total rows to translate: {total_rows}")

    translated_file_name = str(os.path.join(translated_dir_path,
                                 name_of_dataset.replace("/", "_")
                                 )) + split_type + "_" + dialect_name + "_translated.csv"

    # Check how many rows have already been processed
    start_row = 0
    if os.path.isfile(translated_file_name):
        try:
            existing_translations = pd.read_csv(translated_file_name)
            start_row = len(existing_translations)
            if start_row > total_rows:
                print(f"Warning: Existing translations file has more rows ({start_row}) than the dataset ({total_rows}).")
                start_row = 0  # Reset start_row to 0 to reprocess the entire dataset
            else:
                print(f"Resuming from row {start_row + 1}...")
        except Exception as e:
            print(f"Error reading existing translations file: {e}")
            start_row = 0  # Reset if there's an error reading the file

    for chunk_start in range(start_row, total_rows, chunk_size):
        chunk_end = min(chunk_start + chunk_size, total_rows)
        chunk = data_frame.iloc[chunk_start:chunk_end]

        translated_append_list = []
        print(f"Processing rows {chunk_start + 1} to {chunk_end}...")

        for index, val in chunk.iterrows():
            Conversation = val.get("Conversation", "")
            Label = val.get("Label", "")

            if not Conversation or not Label:
                print(f"Skipping row {index + 1} due to missing data.")
                continue

            try:
                conversations = chunk["Conversation"].tolist()
                labels = chunk["Label"].tolist()

                time.sleep(random.uniform(3, 5))

                translated_conversations = GoogleTranslator(source='auto', target=dialect_name).translate_batch(conversations)
                translated_labels = GoogleTranslator(source='auto', target=dialect_name).translate_batch(labels)

                translated_append_list = [{'Conversation': c, 'Label': l} for c, l in zip(translated_conversations, translated_labels)]


            except Exception as e:
                print(f"Error translating index {index}: {e}")

        if translated_append_list:
            df = pd.DataFrame(translated_append_list)
            if not os.path.isfile(translated_file_name) or chunk_start == start_row:
                df.to_csv(translated_file_name, index=False, header=True, mode='w', encoding='utf-8-sig')  # Specify encoding
            else:
                df.to_csv(translated_file_name, index=False, header=False, mode='a', encoding='utf-8-sig')  # Specify encoding

            print(f"Finished writing chunk {chunk_start + 1} to {chunk_end} to file {translated_file_name}")


if __name__ == "__main__":
    ensure_directories_exist()
    # Update the path to your actual dataset file
    dataset_path = r"/content/data/fraud_call_dataset.csv"  # Added `r` to handle special characters in the path

    # Check if the file exists
    if not os.path.isfile(dataset_path):
        raise FileNotFoundError(f"Dataset file not found: {dataset_path}")

    try:
        # Read the CSV file into a pandas DataFrame with encoding fallback
        try:
            df_1 = pd.read_csv(dataset_path, encoding='utf-8')  # Try reading with UTF-8
        except UnicodeDecodeError:
            print("UTF-8 decoding failed. Retrying with ISO-8859-1 encoding...")
            df_1 = pd.read_csv(dataset_path, encoding='ISO-8859-1')  # Fallback to ISO-8859-1

        name_of_dataset = "fraud_call_dataset"  # Added dataset name explicitly
        store_sft_dataset(name_of_dataset, df_1, "dataset")
    except Exception as e:
        print(f"Error reading dataset file: {e}")
# Out:
# Total rows to translate: 20075
# Resuming from row 71...
# Processing rows 71 to 170...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-e5c4c52de058> in <cell line: 0>()
#     125
#     126         name_of_dataset = "fraud_call_dataset"  # Added dataset name explicitly
# --> 127         store_sft_dataset(name_of_dataset, df_1, "dataset")
#     128     except Exception as e:
#     129         print(f"Error reading dataset file: {e}")
#
# <ipython-input-13-e5c4c52de058> in store_sft_dataset(name_of_dataset, data_frame, split_type)
#      30
#      31
# ---> 32     translate_in_dialects(name_of_dataset, data_frame, split_type, translated_dialect)
#      33
#      34 def translate_text_with_retries(text, dest_language, retries=3, delay=5):
#
# <ipython-input-13-e5c4c52de058> in translate_in_dialects(name_of_dataset, data_frame, split_type, dialect_name)
#      88                 time.sleep(random.uniform(3, 5))
#      89
# ---> 90                 translated_conversations = GoogleTranslator(source='auto', target=dialect_name).translate_batch(conversations)
#      91                 translated_labels = GoogleTranslator(source='auto', target=dialect_name).translate_batch(labels)
#      92
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/google.py in translate_batch(self, batch, **kwargs)
#     120         @return: list of translations
#     121         """
# --> 122         return self._translate_batch(batch, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/base.py in _translate_batch(self, batch, **kwargs)
#     179         arr = []
#     180         for i, text in enumerate(batch):
# --> 181             translated = self.translate(text, **kwargs)
#     182             arr.append(translated)
#     183         return arr
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/google.py in translate(self, text, **kwargs)
#      65                 self._url_params[self.payload_key] = text
#      66
# ---> 67             response = requests.get(
#      68                 self._base_url, params=self._url_params, proxies=self.proxies
#      69             )
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.11/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.11/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     744
#     745         if not stream:
# --> 746             r.content
#     747
#     748         return r
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in content(self)
#     900                 self._content = None
#     901             else:
# --> 902                 self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     903
#     904         self._content_consumed = True
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in generate()
#     818             if hasattr(self.raw, "stream"):
#     819                 try:
# --> 820                     yield from self.raw.stream(chunk_size, decode_content=True)
#     821                 except ProtocolError as e:
#     822                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#    1061         """
#    1062         if self.chunked and self.supports_chunked_reads():
# -> 1063             yield from self.read_chunked(amt, decode_content=decode_content)
#    1064         else:
#    1065             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#    1217
#    1218             while True:
# -> 1219                 self._update_chunk_length()
#    1220                 if self.chunk_left == 0:
#    1221                     break
#
# /usr/local/lib/python3.11/dist-packages/urllib3/response.py in _update_chunk_length(self)
#    1136         if self.chunk_left is not None:
#    1137             return None
# -> 1138         line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1139         line = line.split(b";", 1)[0]
#    1140         try:
#
# /usr/lib/python3.11/socket.py in readinto(self, b)
#     716         while True:
#     717             try:
# --> 718                 return self._sock.recv_into(b)
#     719             except timeout:
#     720                 self._timeout_occurred = True
#
# /usr/lib/python3.11/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1312                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313                   self.__class__)
# -> 1314             return self.read(nbytes, buffer)
#    1315         else:
#    1316             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1164         try:
#    1165             if buffer is not None:
# -> 1166                 return self._sslobj.read(len, buffer)
#    1167             else:
#    1168                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import time
import random
from deep_translator import DeeplTranslator

# Paths
SOURCE_DIR = "source"
TRANSLATED_DIR = "translated"
PROGRESS_DIR = "progress"

# Settings
TRANSLATED_LANG = "hi"  # Hindi translation
CHUNK_SIZE = 5000  # Process in chunks of 5000
MAX_RETRIES = 3  # Retries per request
INITIAL_DELAY = 5  # Base delay for backoff
MAX_DELAY = 30  # Max delay

# Ensure directories exist
os.makedirs(SOURCE_DIR, exist_ok=True)
os.makedirs(TRANSLATED_DIR, exist_ok=True)
os.makedirs(PROGRESS_DIR, exist_ok=True)

# Set your DeepL API Key
DEEPL_API_KEY = os.getenv("DEEPL_API_KEY")  # Make sure to set this in your environment
if not DEEPL_API_KEY:
    raise ValueError("DeepL API key not found. Please set the DEEPL_API_KEY environment variable.")

def translate_text(text, target_lang="hi"):
    """
    Translates text using DeepL API.
    """
    translator = DeepL(api_key=DEEPL_API_KEY)
    return translator.translate(text, target_lang=target_lang)

def translate_batch_with_retries(text_list, target_lang="hi", max_retries=MAX_RETRIES):
    """
    Translates a batch of text with retries and exponential backoff.
    """
    attempt = 0
    delay = INITIAL_DELAY
    while attempt < max_retries:
        try:
            translated_texts = [translate_text(text, target_lang) for text in text_list]
            return translated_texts
        except Exception as e:
            print(f"Batch translation failed (attempt {attempt + 1}): {e}")
            attempt += 1
            time.sleep(delay)
            delay = min(delay * 2, MAX_DELAY)
    print("Failed to translate batch after multiple attempts.")
    return text_list

def translate_dataset(name_of_dataset, data_frame, split_type):
    """
    Translates a dataset in large chunks while handling API limits.
    """
    total_rows = len(data_frame)
    print(f"Total rows to translate: {total_rows}")

    translated_file_path = os.path.join(TRANSLATED_DIR, f"{name_of_dataset}_{split_type}_hi_translated.csv")

    # Determine start row to resume progress
    start_row = 0
    if os.path.isfile(translated_file_path):
        try:
            existing_data = pd.read_csv(translated_file_path)
            start_row = len(existing_data)
            if start_row > total_rows:
                print(f"Warning: Translated file has more rows ({start_row}) than dataset ({total_rows}). Resetting progress.")
                start_row = 0
            else:
                print(f"Resuming from row {start_row + 1}...")
        except Exception as e:
            print(f"Error reading existing translations: {e}")
            start_row = 0

    for chunk_start in range(start_row, total_rows, CHUNK_SIZE):
        chunk_end = min(chunk_start + CHUNK_SIZE, total_rows)
        chunk = data_frame.iloc[chunk_start:chunk_end]

        conversations = chunk["Conversation"].dropna().tolist()
        labels = chunk["Label"].dropna().tolist()

        if not conversations or not labels:
            print(f"Skipping empty batch from row {chunk_start + 1} to {chunk_end}.")
            continue

        try:
            print(f"Translating rows {chunk_start + 1} to {chunk_end}...")
            translated_conversations = translate_batch_with_retries(conversations, "hi")
            translated_labels = translate_batch_with_retries(labels, "hi")

            translated_data = pd.DataFrame({"Conversation": translated_conversations, "Label": translated_labels})
            mode = 'w' if chunk_start == start_row else 'a'
            header = chunk_start == start_row

            translated_data.to_csv(translated_file_path, index=False, header=header, mode=mode, encoding='utf-8-sig')

            print(f"Saved rows {chunk_start + 1} to {chunk_end}.")
        except Exception as e:
            print(f"Error translating batch: {e}")

        time.sleep(random.uniform(5, 15))

if __name__ == "__main__":
    dataset_path = r"/content/data/fraud_call_dataset.csv"  # Adjust path

    if not os.path.isfile(dataset_path):
        raise FileNotFoundError(f"Dataset not found: {dataset_path}")

    try:
        try:
            df = pd.read_csv(dataset_path, encoding='utf-8')
        except UnicodeDecodeError:
            print("UTF-8 failed, using ISO-8859-1...")
            df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

        dataset_name = "fraud_call_dataset"
        translate_dataset(dataset_name, df, "dataset")

    except Exception as e:
        print(f"Error loading dataset: {e}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-af94040e1eec> in <cell line: 0>()
#      25 DEEPL_API_KEY = os.getenv("DEEPL_API_KEY")  # Make sure to set this in your environment
#      26 if not DEEPL_API_KEY:
# ---> 27     raise ValueError("DeepL API key not found. Please set the DEEPL_API_KEY environment variable.")
#      28
#      29 def translate_text(text, target_lang="hi"):
#
# ValueError: DeepL API key not found. Please set the DEEPL_API_KEY environment variable.

# %%
import os
import pandas as pd
import time
import random
from deep_translator import GoogleTranslator

# Paths
SOURCE_DIR = "source"
TRANSLATED_DIR = "translated"
PROGRESS_DIR = "progress"

# Settings
TRANSLATED_LANG = "hi"  # Change to your desired language
CHUNK_SIZE = 500  # Large batch processing
MAX_RETRIES = 3  # Retries per batch
INITIAL_DELAY = 5  # Base delay for backoff
MAX_DELAY = 30  # Max delay to prevent infinite wait

# Ensure directories exist
os.makedirs(SOURCE_DIR, exist_ok=True)
os.makedirs(TRANSLATED_DIR, exist_ok=True)
os.makedirs(PROGRESS_DIR, exist_ok=True)

def translate_batch_with_retries(text_list, target_lang, max_retries=MAX_RETRIES):
    """
    Translates a batch of text with retries and exponential backoff.
    """
    translator = GoogleTranslator(source='auto', target=target_lang)
    attempt = 0
    delay = INITIAL_DELAY

    while attempt < max_retries:
        try:
            return translator.translate_batch(text_list)
        except Exception as e:
            print(f"Batch translation failed (attempt {attempt + 1}): {e}")
            attempt += 1
            time.sleep(delay)
            delay = min(delay * 2, MAX_DELAY)  # Exponential backoff with max limit

    print("Failed to translate batch after multiple attempts.")
    return text_list  # Return original text if all attempts fail

def translate_dataset(name_of_dataset, data_frame, split_type, dialect_name="hi"):
    """
    Translates a dataset in large chunks while handling API limits.
    """
    total_rows = len(data_frame)
    print(f"Total rows to translate: {total_rows}")

    translated_file_path = os.path.join(TRANSLATED_DIR, f"{name_of_dataset}_{split_type}_{dialect_name}_translated.csv")

    # Determine start row to resume progress
    start_row = 0
    if os.path.isfile(translated_file_path):
        try:
            existing_data = pd.read_csv(translated_file_path)
            start_row = len(existing_data)
            if start_row > total_rows:
                print(f"Warning: Translated file has more rows ({start_row}) than dataset ({total_rows}). Resetting progress.")
                start_row = 0
            else:
                print(f"Resuming from row {start_row + 1}...")
        except Exception as e:
            print(f"Error reading existing translations: {e}")
            start_row = 0  # Reset progress if there's an error

    # Process in large chunks of 5000
    for chunk_start in range(start_row, total_rows, CHUNK_SIZE):
        chunk_end = min(chunk_start + CHUNK_SIZE, total_rows)
        chunk = data_frame.iloc[chunk_start:chunk_end]

        conversations = chunk["Conversation"].dropna().tolist()
        labels = chunk["Label"].dropna().tolist()

        if not conversations or not labels:
            print(f"Skipping empty batch from row {chunk_start + 1} to {chunk_end}.")
            continue

        try:
            print(f"Translating rows {chunk_start + 1} to {chunk_end}...")
            translated_conversations = translate_batch_with_retries(conversations, dialect_name)
            translated_labels = translate_batch_with_retries(labels, dialect_name)

            translated_data = pd.DataFrame({"Conversation": translated_conversations, "Label": translated_labels})

            mode = 'w' if chunk_start == start_row else 'a'
            header = chunk_start == start_row

            translated_data.to_csv(translated_file_path, index=False, header=header, mode=mode, encoding='utf-8-sig')

            print(f"Saved rows {chunk_start + 1} to {chunk_end}.")
        except Exception as e:
            print(f"Error translating batch: {e}")

        # Randomized delay (5-15 sec) to prevent rate limiting
        time.sleep(random.uniform(5, 15))

if __name__ == "__main__":
    dataset_path = r"/content/data/fraud_call_dataset.csv"  # Adjust path

    if not os.path.isfile(dataset_path):
        raise FileNotFoundError(f"Dataset not found: {dataset_path}")

    try:
        # Read dataset with encoding fallback
        try:
            df = pd.read_csv(dataset_path, encoding='utf-8')
        except UnicodeDecodeError:
            print("UTF-8 failed, using ISO-8859-1...")
            df = pd.read_csv(dataset_path, encoding='ISO-8859-1')

        dataset_name = "fraud_call_dataset"
        translate_dataset(dataset_name, df, "dataset", TRANSLATED_LANG)

    except Exception as e:
        print(f"Error loading dataset: {e}")
# Out:
# Total rows to translate: 20075
# Resuming from row 4001...
# Translating rows 4001 to 4500...
# Batch translation failed (attempt 1): Server Error: You made too many requests to the server.According to google, you are allowed to make 5 requests per secondand up to 200k requests per day. You can wait and try again later oryou can try the translate_batch function
# Batch translation failed (attempt 2): Server Error: You made too many requests to the server.According to google, you are allowed to make 5 requests per secondand up to 200k requests per day. You can wait and try again later oryou can try the translate_batch function
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-25-c616eb80a4a9> in translate_batch_with_retries(text_list, target_lang, max_retries)
#      33         try:
# ---> 34             return translator.translate_batch(text_list)
#      35         except Exception as e:
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/google.py in translate_batch(self, batch, **kwargs)
#     121         """
# --> 122         return self._translate_batch(batch, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/base.py in _translate_batch(self, batch, **kwargs)
#     180         for i, text in enumerate(batch):
# --> 181             translated = self.translate(text, **kwargs)
#     182             arr.append(translated)
#
# /usr/local/lib/python3.11/dist-packages/deep_translator/google.py in translate(self, text, **kwargs)
#      70             if response.status_code == 429:
# ---> 71                 raise TooManyRequests()
#      72
#
# TooManyRequests: Server Error: You made too many requests to the server.According to google, you are allowed to make 5 requests per secondand up to 200k requests per day. You can wait and try again later oryou can try the translate_batch function
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-c616eb80a4a9> in <cell line: 0>()
#     112
#     113         dataset_name = "fraud_call_dataset"
# --> 114         translate_dataset(dataset_name, df, "dataset", TRANSLATED_LANG)
#     115
#     116     except Exception as e:
#
# <ipython-input-25-c616eb80a4a9> in translate_dataset(name_of_dataset, data_frame, split_type, dialect_name)
#      80         try:
#      81             print(f"Translating rows {chunk_start + 1} to {chunk_end}...")
# ---> 82             translated_conversations = translate_batch_with_retries(conversations, dialect_name)
#      83             translated_labels = translate_batch_with_retries(labels, dialect_name)
#      84
#
# <ipython-input-25-c616eb80a4a9> in translate_batch_with_retries(text_list, target_lang, max_retries)
#      36             print(f"Batch translation failed (attempt {attempt + 1}): {e}")
#      37             attempt += 1
# ---> 38             time.sleep(delay)
#      39             delay = min(delay * 2, MAX_DELAY)  # Exponential backoff with max limit
#      40
#
# KeyboardInterrupt:
